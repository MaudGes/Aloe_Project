# %%
import pandas as pd
import numpy as np
import string as str
import os
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime

# %% [markdown]
# Tables importation and naming

# %%
sales = pd.read_csv("Aloe_Project_Sales.csv", sep=";")
clients = pd.read_csv("Aloe_Project_Clients.csv", sep=";")
salesreps = pd.read_csv("Aloe_Project_Sales_rep.csv", sep = ";")

# %% [markdown]
# Assigning the right types to the tables columns

# %%
#Sales
sales["code_cip_id"] = sales["code_cip_id"].astype("str")
sales["salesrep_id"] = sales["salesrep_id"].astype("str")
sales["quantity"] = sales["quantity"].astype("int")
sales["order_date"] = pd.to_datetime(sales["order_date"])

#Clients
clients["code_cip_id"] = clients["code_cip_id"].astype("str")
clients["postal_code"] = clients["postal_code"].astype("str")

#Sales_reps
salesreps["salesrep_id"] = salesreps["salesrep_id"].astype("str")

# %% [markdown]
# Data cleaning

# %%
#Removing special characters from the products' names and replacing them with the right ones
sales["article_name"] = sales["article_name"].apply(lambda x : x.replace("Ã©", "é").replace("Ãª", "ê").replace("Ã¨", "è"))

# %% [markdown]
# Some product's names contain what is called an EAN number at the end, it needs to be removed
# All EAN numbers start with "- 8.02"

# %%
#Using a loop to go through the column, find the EAN number, split the string in two and keep the first part

new_values = []
for i, v in sales["article_name"].items():
    if "- 8.02" in v:
            v = v.replace("- 8.02", "removeafterthat")
            sep = "removeafterthat"
            v = v.split(sep, 1)[0]
            new_values.append(v)
    elif "- 8.02" not in v:
            v = v
            new_values.append(v)

sales["article_name"] = new_values

# %%
#Check
sales["article_name"].unique()
# Out:
# array(['Vide', 'Nutri-Pulpe 1000ml ', 'Nutri-Pulpe 500ml ',
#        'Nutri-Pulpe Pêche Blanche 1000ml ',
#        'Nutri-Pulpe Pêche Blanche 500ml ', 'Pur Gel Feuille 250ml ',
#        'Pur Gel Flacon 100ml ', 'Aloe-Oil Huile Réparatrice 50ml ',
#        "Cœur d'Aloe Cube", 'Totem Double Face',
#        'Pop-Up Coeur D’Aloe Cube Offre Consommateur',
#        'Présentoir de Sol Gamme Aloe',
#        'Grand Aloe Vera Cartonné de Linéaire ou Vitrine',
#        'Brochure Gamme Aloe Vera', 'Echantillon Nutri-Pulpe',
#        'Echantillon Pur Gel',
#        'Echantillon Nutri-Pulpe Goût Pêche Blanche',
#        'Aloe-Oil Crème Réparatrice 150ml ',
#        'Présentoir de Comptoir Aloe-Oil',
#        'Réglette De Linéaire Aloe Vera',
#        'Présentoir de Comptoir Gamme Aloe', "Cœur d'aloe cube",
#        'Réglette de linéaire Aloe Vera', 'Totem double face',
#        'Grand aloe vera cartonné de linéaire ou vitrine',
#        'Pur Gel Feuille - 250ml ', 'Pur Gel Flacon - 100ml ',
#        'Aloe-Oil Huile Réparatrice - 50ml ',
#        'Aloe-Oil Crème Réparatrice - 150ml ',
#        "Pop-up cœur d'aloe cube offre consommateur",
#        'Pur gel feuille - 250ml', 'Pur gel flacon - 100ml',
#        'Aloe-oil huile réparatrice - 50ml',
#        'Aloe-oil crème réparatrice - 150ml',
#        'Présentoir de comptoir Nutri-Pulpe & Pur Gel',
#        'Présentoir de comptoir gamme Aloe-oil',
#        'Brochure de gamme Aloe Vera consommateur',
#        'Nutri-Pulpe - 1000ml ', 'Nutri-Pulpe Pêche Blanche - 1000ml ',
#        'Nutri-Pulpe Pêche Blanche - 500ml ', 'Présentoir de Sol Aloe-Oil',
#        'Echantillon Aloe-oil huile réparatrice',
#        'Echantillon Aloe-oil crème réparatrice', 'Nutri-Pulpe - 500ml ',
#        'Aloe-Oil Huile Reparatrice 50ml ',
#        'Nutri-pulpe goût pêche blanche - 500ml',
#        'Echantillon Aloe-Oil Huile Réparatrice',
#        'Echantillon Aloe-Oil Crème Réparatrice',
#        'Aloe-Oil Creme Reparatrice 150ml ',
#        'Reglette De Lineaire Aloe Vera',
#        'Presentoir de Comptoir Gamme Aloe',
#        'Grand Aloe Vera Cartonne de Lineaire ou Vitrine',
#        'Echantillon Aloe-Oil Creme Reparatrice',
#        'Echantillon Aloe-Oil Huile Reparatrice',
#        'Gyn-Aloe Soin Lavant Flacon 250ml ',
#        'Presentoir de Comptoir Aloe-Oil',
#        'Echantillon Nutri-Pulpe goût pêche blanche',
#        'Nutri-pulpe - 500ml', 'Présentoir de sol Nutri-Pulpe & Pur Gel',
#        'UG Aloe-Oil Huile Réparatrice 50ml', 'Pure Creme 400ml ',
#        'Echantillon Pure Creme',
#        'Présentoir de comptoir ou d’étagère Gyn-Aloe',
#        'Gyn-Aloe Soin Lavant Pompe 400ml ',
#        'Echantillon Gyn-Aloe Soin Lavant', 'Nutri-Pulpe Immunité 1000ml ',
#        'Echantillon Nutri-Pulpe Immunité', 'Presentoir de Sol Gamme Aloe',
#        'Presentoir de Sol Aloe-Oil', 'Pure Crème 400ml ',
#        'Echantillon Pure Crème', 'Basette Présentoir Gyn-Aloe',
#        'Gyn-Aloe Soin Lavant - 250ml ',
#        'Presentoir de comptoir ou d’etagere Gyn-Aloe',
#        'Nutri-Pulpe Immunite 1000ml ', 'Echantillon Nutri-Pulpe Immunite',
#        'UG Nutri-Aloe 1000ml', 'UG Pur Gel Flacon 100ml',
#        'UG Pure Crème 400ml', 'UG Gyn-Aloe Soin Lavant Pompe 400ml',
#        'UG Gyn-Aloe Soin Lavant Flacon 250ml',
#        'UG Nutri-Pulpe Immunité 1000ml',
#        'UG Aloe-Oil Crème Réparatrice 150ml', 'Pure Crème - 400ml ',
#        'Gyn-Aloe Soin Lavant - 400ml ', 'Nutri-Pulpe Immunité - 1000ml ',
#        'Pur Gel Aloe Bio Pompe 300ml ', 'Cyst-Aloe Sticks Flash 15x10ml ',
#        'UG Pur Gel Feuille 250ml', 'UG Nutri-Aloe Pêche Blanche 1000ml',
#        'UG Nutri-Aloe 500ml', 'UG Nutri-Aloe Pêche Blanche 500ml'],
#       dtype=object)

# %%
#Removing spaces from the products' names
sales["article_name"] = sales["article_name"].apply(lambda x: x.strip())
#Adding caps at the begining of each word (some products are named the same but not recognised as the same because of caps changes)
sales["article_name"] = sales["article_name"].apply(lambda x: str.capwords(x, " "))

# %%
# Removing hyhens from products names, for example "Pur Gel Feuille - 250ml" = "Pur Gel Feuille 250ml"
without_hyphen = []
for i, v in sales["article_name"].items():
    if " - " in v:
        v = v.replace(" - ", " ")
        without_hyphen.append(v)
    elif " - " not in v:
        v = v
        without_hyphen.append(v)
    
sales["article_name"] = without_hyphen

# %% [markdown]
# The original excel file contains summary rows that are actually the sum of the rows below
# (calculating the total revenue, and total product quantity of an order for example).They need to be removed.
# The article name is always "Vide" for these rows.
#
# There are a lot of nans in "unit_price", they are linked to sample or brochure giving.
#
# There are also rows with 0 as a "unit price", they are linked to orders with 100% discount (mainly the same situation than brochure giving)

# %%
#Finding and deleting the "sum rows" + finding and deleting the "Ug" rows (containing free units)
empty_names_indexes = []
Ug_indexes = []

for i,v in sales["article_name"].items():
    if "Vide" in v:
        empty_names_indexes.append(i)
    if "Ug" in v:
        Ug_indexes.append(i)
        
sales = sales.drop(empty_names_indexes)
sales = sales.drop(Ug_indexes)

# %%
#Finding and deleting the "NANs" in unit_price
sales = sales.dropna(subset = ["unit_price"])

# %%
#Finding and deleting the "0" in unit_price
zeros_in_price_indexes = [i for i,v in sales["unit_price"].items() if v == 0]
sales = sales.drop(zeros_in_price_indexes)

# %%
sales["unit_price"]
# Out:
# 1        24.9
# 2        16.9
# 3        24.9
# 4        16.9
# 5        16.9
#          ...
# 18615    12.5
# 18616    16.1
# 18618    16.9
# 18619     9.9
# 18620    16.9
# Name: unit_price, Length: 6925, dtype: float64

# %%
sales.describe()
# Out:
#         primary_key     quantity   unit_price  net_revenue  Unnamed: 11
# count   6925.000000  6925.000000  6925.000000  6925.000000          0.0
# mean   11518.480289    11.568087    15.531509    97.087374          NaN
# std     6609.612447    10.097096     4.743798    86.671938          NaN
# min       89.000000     1.000000     8.900000     0.000000          NaN
# 25%     5579.000000     6.000000     9.900000    59.890000          NaN
# 50%    10934.000000    12.000000    16.900000    73.660000          NaN
# 75%    17425.000000    12.000000    16.900000   118.300000          NaN
# max    22144.000000   150.000000    27.900000  1807.740000          NaN

# %% [markdown]
# CREATING A CLEAN SALES EXCEL FILE TO ANALYSE IN TABLEAU

# %%
sales.to_excel("cleaned_sales.xlsx", sheet_name='sales')

# %% [markdown]
# In this part, I will take a quick look at the main KPIs before importing the data in tableau

# %% [markdown]
# Merging the clients and sales tables. Common key : code_cip_id

# %%
clients_sales = sales.merge(clients)
clients_sales
# Out:
#       primary_key  order_reference code_cip_id salesrep_id article_code  \
# 0           19561  2105202234S0001     2260084          26         5046
# 1           19562  2105202234S0001     2260084          26         5047
# 2           19563  2105202234S0001     2260084          26         5048
# 3           19564  2105202234S0001     2260084          26         5049
# 4           19565  2105202234S0001     2260084          26         5050
# ...           ...              ...         ...         ...          ...
# 6841        10459  2605220959S0003     2051212          29         5046
# 6842        10460  2605220959S0003     2051212          29         5047
# 6843        10461  2605220959S0003     2051212          29         5048
# 6844        10462  2605220959S0003     2051212          29         5049
# 6845        10463  2605220959S0003     2051212          29         5602
#
#                           article_name  quantity  unit_price discount  \
# 0                   Nutri-pulpe 1000ml        12        24.9      38%
# 1                    Nutri-pulpe 500ml        12        16.9      38%
# 2     Nutri-pulpe Pêche Blanche 1000ml         6        24.9      38%
# 3      Nutri-pulpe Pêche Blanche 500ml         6        16.9      38%
# 4                Pur Gel Feuille 250ml        36        16.9      38%
# ...                                ...       ...         ...      ...
# 6841                Nutri-pulpe 1000ml         6        24.9      38%
# 6842                 Nutri-pulpe 500ml         6        16.9      38%
# 6843  Nutri-pulpe Pêche Blanche 1000ml         6        24.9      38%
# 6844   Nutri-pulpe Pêche Blanche 500ml         6        16.9      38%
# 6845       Nutri-pulpe Immunité 1000ml         6        27.9      38%
#
#       net_revenue order_date  Unnamed: 11    uga    pharmacies_name  \
# 0          185.26 2020-05-22          NaN  83SMA  PHARMACY NUM17193
# 1          125.74 2020-05-22          NaN  83SMA  PHARMACY NUM17193
# 2           92.63 2020-05-22          NaN  83SMA  PHARMACY NUM17193
# 3           62.87 2020-05-22          NaN  83SMA  PHARMACY NUM17193
# 4          377.21 2020-05-22          NaN  83SMA  PHARMACY NUM17193
# ...           ...        ...          ...    ...                ...
# 6841        92.63 2022-05-27          NaN  95PON  PHARMACY NUM19934
# 6842        62.87 2022-05-27          NaN  95PON  PHARMACY NUM19934
# 6843        92.63 2022-05-27          NaN  95PON  PHARMACY NUM19934
# 6844        62.87 2022-05-27          NaN  95PON  PHARMACY NUM19934
# 6845       103.79 2022-05-27          NaN  95PON  PHARMACY NUM19934
#
#      appellation_titulaire owner_last_name owner_first_name  commune  \
# 0                      Mme         Terence         Guilaine  COGOLIN
# 1                      Mme         Terence         Guilaine  COGOLIN
# 2                      Mme         Terence         Guilaine  COGOLIN
# 3                      Mme         Terence         Guilaine  COGOLIN
# 4                      Mme         Terence         Guilaine  COGOLIN
# ...                    ...             ...              ...      ...
# 6841                     M          Quincy          Camille    CERGY
# 6842                     M          Quincy          Camille    CERGY
# 6843                     M          Quincy          Camille    CERGY
# 6844                     M          Quincy          Camille    CERGY
# 6845                     M          Quincy          Camille    CERGY
#
#      postal_code
# 0          83310
# 1          83310
# 2          83310
# 3          83310
# 4          83310
# ...          ...
# 6841       95000
# 6842       95000
# 6843       95000
# 6844       95000
# 6845       95000
#
# [6846 rows x 19 columns]

# %% [markdown]
# Merging the sales rep and sales tables

# %%
#Left join because some sales reps have not sold any products yet, need to identify them
salesreps_sales = salesreps.merge(sales, how = "left")

# %%
salesreps_sales
# Out:
#      salesrep_id last_name first_name  primary_key  order_reference  \
# 0              1    Martin      Marie      16110.0  1707211740S0001
# 1              1    Martin      Marie      16111.0  1707211740S0001
# 2              1    Martin      Marie      16115.0  1707211651S0001
# 3              1    Martin      Marie      16121.0  1707211651S0001
# 4              1    Martin      Marie      16122.0  1707211651S0001
# ...          ...       ...        ...          ...              ...
# 6944          54    Dumont     Salomé       2037.0  2305221503S0019
# 6945          54    Dumont     Salomé       2038.0  2305221503S0019
# 6946          54    Dumont     Salomé       8508.0  2305221503S0019
# 6947          54    Dumont     Salomé       8509.0  2305221503S0019
# 6948          55     Marie   Jean-Guy          NaN              NaN
#
#      code_cip_id article_code                      article_name  quantity  \
# 0        2249689         5050             Pur Gel Feuille 250ml      24.0
# 1        2249689         5051              Pur Gel Flacon 100ml      24.0
# 2        2003434         5051              Pur Gel Flacon 100ml      12.0
# 3        2003434         5597                  Pure Crème 400ml      12.0
# 4        2003434         5598  Gyn-aloe Soin Lavant Pompe 400ml       6.0
# ...          ...          ...                               ...       ...
# 6944     2265606         5050             Pur Gel Feuille 250ml      24.0
# 6945     2265606         5051              Pur Gel Flacon 100ml      24.0
# 6946     2265606         5050             Pur Gel Feuille 250ml      24.0
# 6947     2265606         5051              Pur Gel Flacon 100ml      24.0
# 6948         NaN          NaN                               NaN       NaN
#
#       unit_price discount  net_revenue order_date  Unnamed: 11
# 0           16.9      55%       182.52 2021-07-19          NaN
# 1            9.9      55%       106.92 2021-07-19          NaN
# 2            9.9      45%        65.34 2021-07-19          NaN
# 3           14.9      45%        98.34 2021-07-19          NaN
# 4           16.1      45%        53.13 2021-07-19          NaN
# ...          ...      ...          ...        ...          ...
# 6944        16.9      55%       182.52 2022-05-24          NaN
# 6945         9.9      55%       106.92 2022-05-24          NaN
# 6946        16.9      55%       182.52 2022-05-24          NaN
# 6947         9.9      55%       106.92 2022-05-24          NaN
# 6948         NaN      NaN          NaN        NaT          NaN
#
# [6949 rows x 14 columns]

# %% [markdown]
# SALES ANALYSIS

# %% [markdown]
# UGA analysis

# %%
#Top 10 UGA _ everything since 2020
top_10_ugas = clients_sales.groupby("uga")["net_revenue"].sum().sort_values(ascending = False).head(10)
top_10_ugas.to_frame()
# Out:
#        net_revenue
# uga
# 83DRA     61715.96
# 06CAG     39381.64
# 33BD3     16986.24
# 83SMA     16516.13
# 06GRA     16404.42
# 93ROS     14609.28
# 83FRE     13670.81
# 13M05     12513.29
# 83TL2     11414.95
# 06VEN     11023.18

# %% [markdown]
# UGA graph analysis (categorical plot)

# %%
#Top 10 UGAs plotting

# %%
top_10_uga = top_10_ugas.reset_index()
sns.catplot(data=top_10_uga, x="uga", y = "net_revenue", kind = "bar")
plt.gcf().set_size_inches(28,30)
plt.show()

# %% [markdown]
# Large discrepancies between UGA's revenues

# %%
#Finding the top 25 products for each UGAs
#Top 25 products with related UGAs _ everything since 2020
clients_sales.groupby(["uga", "article_name"])["net_revenue"].sum().sort_values(ascending = False).to_frame().head(25)
# Out:
#                                         net_revenue
# uga   article_name
# 83DRA Pur Gel Feuille 250ml                15907.69
# 06CAG Pur Gel Feuille 250ml                10434.09
# 83DRA Pur Gel Flacon 100ml                 10431.86
#       Aloe-oil Crème Réparatrice 150ml      7993.22
# 33BD3 Nutri-pulpe 1000ml                    7230.96
# 83DRA Aloe-oil Huile Réparatrice 50ml       6564.10
#       Nutri-pulpe 1000ml                    5765.38
# 06CAG Pur Gel Flacon 100ml                  5104.85
# 83SMA Pur Gel Feuille 250ml                 4966.58
# 33BD3 Nutri-pulpe 500ml                     4907.76
# 06CAG Nutri-pulpe 1000ml                    4673.24
# 13M05 Pur Gel Feuille 250ml                 4585.32
# 83FRE Pur Gel Feuille 250ml                 4305.45
# 06GRA Pur Gel Feuille 250ml                 3849.16
# 83SAN Pur Gel Feuille 250ml                 3814.68
# 06CAG Aloe-oil Crème Réparatrice 150ml      3704.10
# 83DRA Nutri-pulpe 500ml                     3646.37
# 06CAG Nutri-pulpe 500ml                     3610.87
# 83TL2 Pur Gel Feuille 250ml                 3526.73
# 59VAL Pur Gel Feuille 250ml                 3520.58
# 93ROS Pur Gel Feuille 250ml                 3513.54
# 06CAG Aloe-oil Huile Réparatrice 50ml       3336.30
# 92GEN Pur Gel Feuille 250ml                 3054.24
# 59ROU Pur Gel Feuille 250ml                 3017.70
# 83DRA Nutri-pulpe Pêche Blanche 1000ml      2929.75

# %%
#Tail 10 UGA _ everything since 2020
clients_sales.groupby("uga")["net_revenue"].sum().sort_values(ascending = False).tail(10).to_frame()
# Out:
#        net_revenue
# uga
# 85LSA       328.20
# 37LOC       324.77
# 75AUT       310.26
# 84CAR       292.03
# 84ORA       281.24
# 69BEL       281.24
# 29CON       251.48
# 42FEU       241.38
# 75CLI       205.13
# 43LPU       182.52

# %% [markdown]
# Products

# %%
#Top 10 produtcs _ everything since 2020
sales.groupby("article_name")["net_revenue"].sum().sort_values(ascending = False).head(10).to_frame()
# Out:
#                                    net_revenue
# article_name
# Pur Gel Feuille 250ml              184426.3700
# Pur Gel Flacon 100ml                98695.2700
# Aloe-oil Crème Réparatrice 150ml    64822.4400
# Aloe-oil Huile Réparatrice 50ml     59785.2825
# Nutri-pulpe 1000ml                  53145.9600
# Nutri-pulpe 500ml                   52402.1700
# Nutri-pulpe Pêche Blanche 500ml     47444.5100
# Nutri-pulpe Pêche Blanche 1000ml    31723.4500
# Pure Crème 400ml                    27015.6600
# Gyn-aloe Soin Lavant Flacon 250ml   18337.2500

# %% [markdown]
# All products sales over time_Grouper par le mois de l'order date pour avoir un graph par mois.

# %%
all_sales_over_time = clients_sales[["article_name","net_revenue","order_date"]]
all_sales_over_time = all_sales_over_time.groupby(["order_date"])["net_revenue"].sum()
all_sales_over_time = all_sales_over_time.reset_index()
all_sales_over_time
# Out:
#     order_date  net_revenue
# 0   2020-05-22      3401.26
# 1   2020-05-26       860.84
# 2   2020-05-27       546.85
# 3   2020-05-29       325.14
# 4   2020-06-02       383.92
# ..         ...          ...
# 406 2022-05-24      1413.97
# 407 2022-05-25      1422.89
# 408 2022-05-27      1090.39
# 409 2022-05-30       600.74
# 410 2022-05-31      1648.20
#
# [411 rows x 2 columns]

# %%
sns.lineplot(data = all_sales_over_time, x = "order_date", y = "net_revenue" )
plt.gcf().set_size_inches(30,30)
plt.show()

# %% [markdown]
# ALL product sales in 2020 and 2021 2022

# %% [markdown]
# 2020

# %%
start = pd.to_datetime("2020-01-01")
end = pd.to_datetime("2020-12-01")
sales_2020_over_time = clients_sales[clients_sales["order_date"].between(start,end)]
sales_2020_over_time.sort_values(by = ["order_date"])
# Out:
#       primary_key  order_reference code_cip_id salesrep_id article_code  \
# 0           19561  2105202234S0001     2260084          26         5046
# 65          19634  2005201439S0001     2006719          26         5050
# 66          19635  2005201439S0001     2006719          26         5052
# 57          19602  2005201446S0001     2212245          26         5051
# 56          19601  2005201446S0001     2212245          26         5050
# ...           ...              ...         ...         ...          ...
# 380         19608  0112203144S0001     2213144          26         5050
# 379         19607  0112203144S0001     2213144          26         5049
# 378         19606  0112203144S0001     2213144          26         5048
# 2609         1841  2711201623S0005     2180287          34         5049
# 2621        21408  2711201623S0005     2180287          34         5053
#
#                           article_name  quantity  unit_price discount  \
# 0                   Nutri-pulpe 1000ml        12        24.9      38%
# 65               Pur Gel Feuille 250ml        12        16.9      38%
# 66     Aloe-oil Huile Réparatrice 50ml        12         8.9      38%
# 57                Pur Gel Flacon 100ml        12         9.9      38%
# 56               Pur Gel Feuille 250ml        12        16.9      38%
# ...                                ...       ...         ...      ...
# 380              Pur Gel Feuille 250ml        36        16.9      46%
# 379    Nutri-pulpe Pêche Blanche 500ml        12        16.9      46%
# 378   Nutri-pulpe Pêche Blanche 1000ml         6        24.9      46%
# 2609   Nutri-pulpe Pêche Blanche 500ml         3        16.9      30%
# 2621  Aloe-oil Crème Réparatrice 150ml         3        15.9      30%
#
#       net_revenue order_date  Unnamed: 11    uga    pharmacies_name  \
# 0          185.26 2020-05-22          NaN  83SMA  PHARMACY NUM17193
# 65         125.74 2020-05-22          NaN  83DRA  PHARMACY NUM17333
# 66          66.22 2020-05-22          NaN  83DRA  PHARMACY NUM17333
# 57          73.66 2020-05-22          NaN  83FRE  PHARMACY NUM17342
# 56         125.74 2020-05-22          NaN  83FRE  PHARMACY NUM17342
# ...           ...        ...          ...    ...                ...
# 380        328.54 2020-12-01          NaN  83TL2  PHARMACY NUM17033
# 379        109.51 2020-12-01          NaN  83TL2  PHARMACY NUM17033
# 378         80.68 2020-12-01          NaN  83TL2  PHARMACY NUM17033
# 2609        35.49 2020-12-01          NaN  70VES  PHARMACY NUM13801
# 2621        33.39 2020-12-01          NaN  70VES  PHARMACY NUM13801
#
#      appellation_titulaire owner_last_name owner_first_name     commune  \
# 0                      Mme         Terence         Guilaine     COGOLIN
# 65                       M          Mayssa         Gertrude    SALERNES
# 66                       M          Mayssa         Gertrude    SALERNES
# 57                       M         Matthéo              Gui  ST RAPHAEL
# 56                       M         Matthéo              Gui  ST RAPHAEL
# ...                    ...             ...              ...         ...
# 380                      M          Marine          Mabelle      TOULON
# 379                      M          Marine          Mabelle      TOULON
# 378                      M          Marine          Mabelle      TOULON
# 2609                   Mme          Maryne            Blank  ST SAUVEUR
# 2621                   Mme          Maryne            Blank  ST SAUVEUR
#
#      postal_code
# 0          83310
# 65         83690
# 66         83690
# 57         83700
# 56         83700
# ...          ...
# 380        83000
# 379        83000
# 378        83000
# 2609       70300
# 2621       70300
#
# [1404 rows x 19 columns]

# %%
sales_2020_over_time = sales_2020_over_time[["article_name", "net_revenue", "order_date"]]
sales_2020_over_time = sales_2020_over_time.groupby("order_date")["net_revenue"].sum()
sales_2020_over_time =sales_2020_over_time.reset_index()
sns.lineplot(data = sales_2020_over_time, x = "order_date", y = "net_revenue" )
plt.show()
plt.gcf().set_size_inches(28,30)

# %% [markdown]
# Sales peek due to high sale of "Pur Gel Feuille 250ml" on the related days

# %%
#Tails 10 products _ everything since 2020
sales.groupby("article_name")["net_revenue"].sum().sort_values(ascending = False).tail(25).to_frame()
# Out:
#                                       net_revenue
# article_name
# Pur Gel Feuille 250ml                 184426.3700
# Pur Gel Flacon 100ml                   98695.2700
# Aloe-oil Crème Réparatrice 150ml       64822.4400
# Aloe-oil Huile Réparatrice 50ml        59785.2825
# Nutri-pulpe 1000ml                     53145.9600
# Nutri-pulpe 500ml                      52402.1700
# Nutri-pulpe Pêche Blanche 500ml        47444.5100
# Nutri-pulpe Pêche Blanche 1000ml       31723.4500
# Pure Crème 400ml                       27015.6600
# Gyn-aloe Soin Lavant Flacon 250ml      18337.2500
# Nutri-pulpe Immunité 1000ml            12739.7800
# Gyn-aloe Soin Lavant Pompe 400ml       12600.0100
# Pure Creme 400ml                        2486.5600
# Aloe-oil Huile Reparatrice 50ml         2157.8825
# Aloe-oil Creme Reparatrice 150ml        2087.6600
# Nutri-pulpe Immunite 1000ml              919.5900
# Gyn-aloe Soin Lavant 250ml               783.0000
# Gyn-aloe Soin Lavant 400ml               324.5700
# Nutri-pulpe Goût Pêche Blanche 500ml     188.6100
# Pur Gel Aloe Bio Pompe 300ml             133.1800
# Cyst-aloe Sticks Flash 15x10ml           110.8600

# %% [markdown]
# Sales Rep

# %%
#Top 10 sales reps (sellers)_ everything since 2020
salesreps_sales.groupby("first_name")["net_revenue"].sum().sort_values(ascending = False).head(10).to_frame()
# Out:
#             net_revenue
# first_name
# Louis         148182.61
# Marie         119901.29
# Olivia         52391.69
# Pauline        49776.63
# Bernard        42438.30
# Jacques        35591.50
# René           29187.53
# Lara           28891.19
# Marcel         25453.50
# Georges        20730.92

# %%
#last 12 sellers_everything since 2020
salesreps_sales.groupby("first_name")["net_revenue"].sum().sort_values(ascending = False).tail(12).to_frame()
# Out:
#             net_revenue
# first_name
# Christiane          0.0
# Marguerite          0.0
# Christine           0.0
# Madeleine           0.0
# Louise              0.0
# Claire              0.0
# Denise              0.0
# Françoise           0.0
# Jeanne              0.0
# Jean-Guy            0.0
# Jacqueline          0.0
# Monique             0.0

# %% [markdown]
# Buyers

# %%
#Top 10 buyers_ everything since 2020
clients_sales[["code_cip_id", "pharmacies_name","net_revenue"]].groupby(["code_cip_id","pharmacies_name"])["net_revenue"].sum().sort_values(ascending = False).to_frame().head(10)
# Out:
#                                net_revenue
# code_cip_id pharmacies_name
# 2102240     PHARMACY NUM5440      16986.24
# 2241522     PHARMACY NUM986       13073.40
# 2048765     PHARMACY NUM19194     13037.88
# 2007231     PHARMACY NUM1764      10593.30
# 2042674     PHARMACY NUM17261      9475.77
# 2235131     PHARMACY NUM19862      7107.75
# 2042412     PHARMACY NUM17325      6884.95
# 2012778     PHARMACY NUM1003       6788.37
# 2242919     PHARMACY NUM17204      6706.52
# 2012758     PHARMACY NUM861        6343.77
